# %%
import gym
import Trial_gym
from IPython.display import clear_output

env = gym.make('trial_gym-v0')
for _ in range(1000):
#     clear_output(wait=True)
    env.reset()
    env.render()
    env.step(env.action_space.sample())
# Out:
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ---
# ---
# ---
#
# ...
